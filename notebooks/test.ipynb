# %% [markdown]
# # Home Credit Default Risk — Understanding Test
#
# **Total:** 50 marks
# ---
#
# # Section A — Core Concepts
#
# ## Q1. Class Imbalance — 3 marks
#
# Our target distribution is approximately:
#
# ```text
# TARGET = 0 → 91.93%
# TARGET = 1 → 8.07%
# ```
#
# A model predicts `0` for every applicant.
#
# **a.** What accuracy would this model achieve approximately?
#
# **b.** What would its recall for the positive class be?
#
# **c.** Explain why accuracy alone would be misleading in this problem.
#
# ---
#
# ## Q2. Stratification — 2 marks
#
# Why did we use:
#
# ```python
# train_test_split(
#     X, y,
#     test_size=0.20,
#     stratify=y,
#     random_state=42
# )
# ```
#
# What problem does `stratify=y` solve?
#
# ---
#
# ## Q3. Train, Validation and Test — 3 marks
#
# Explain the difference between:
#
# 1. Training set
# 2. Validation/development data
# 3. Final test/holdout data
#
# Why should we **not repeatedly use the final holdout set** while developing the model?
#
# ---
#
# ## Q4. Data Leakage — 3 marks
#
# Suppose you calculate the median income using:
#
# ```python
# df["AMT_INCOME_TOTAL"].median()
# ```
#
# using the **entire dataset**, and then split the data into train and validation sets.
#
# Explain why this can technically constitute data leakage.
#
# What is the correct approach?
#
# ---
#
# # Section B — Feature Engineering
#
# ## Q5. Ratio Features — 3 marks
#
# We created:
#
# $$
# CreditIncomeRatio =
# \frac{AMT\_CREDIT}{AMT\_INCOME\_TOTAL}
# $$
#
# Why might this feature contain information that `AMT_CREDIT` and `AMT_INCOME_TOTAL` individually don't capture as effectively?
#
# Give a real-world interpretation of a high value.
#
# ---
#
# ## Q6. Multicollinearity — 4 marks
#
# Initially we had:
#
# ```text
# AMT_CREDIT
# AMT_GOODS_PRICE
# AMT_ANNUITY
# CREDIT_INCOME_RATIO
# ANNUITY_INCOME_RATIO
# CREDIT_GOODS_RATIO
# ```
#
# and obtained very high VIF values, including values above 100.
#
# **a.** What does a high VIF indicate?
#
# **b.** Why can multicollinearity make logistic-regression coefficients unstable?
#
# **c.** Does high VIF necessarily mean the model's predictive performance will be poor?
#
# Explain.
#
# ---
#
# ## Q7. Replacement vs Addition — 3 marks
#
# We eventually removed:
#
# ```text
# AMT_ANNUITY
# AMT_GOODS_PRICE
# ```
#
# while retaining some ratios derived from them.
#
# Why can **replacing** highly correlated variables with more meaningful ratios sometimes be preferable to simply adding the ratios?
#
# ---
#
# ## Q8. Sentinel Values — 3 marks
#
# `DAYS_EMPLOYED` contained:
#
# ```text
# 365243
# ```
#
# for approximately 18% of applicants.
#
# We created:
#
# ```python
# DAYS_EMPLOYED_ANOMALY
# ```
#
# and replaced `365243` with `NaN`.
#
# Explain:
#
# **a.** Why treating `365243` as a genuine number would be problematic.
#
# **b.** Why is the anomaly indicator useful?
#
# **c.** Why might simply replacing the value with the median lose information?
#
# ---
#
# ## Q9. Transformation — 3 marks
#
# We created:
#
# ```python
# AGE_YEARS = -DAYS_BIRTH / 365.25
# AGE_SQUARED = AGE_YEARS ** 2
# LOG_INCOME = np.log1p(AMT_INCOME_TOTAL)
# ```
#
# Explain the motivation behind each transformation.
#
# In particular, why might `LOG_INCOME` be more useful to a linear model than raw income?
#
# ---
#
# # Section C — Logistic Regression
#
# ## Q10. Logistic Regression — 3 marks
#
# Given:
#
# $$
# z=\beta_0+\beta_1x_1+\cdots+\beta_px_p
# $$
#
# and:
#
# $$
# p=\frac{1}{1+e^{-z}}
# $$
#
# answer:
#
# **a.** What does \(p\) represent?
#
# **b.** What happens to \(p\) when $$z\rightarrow+\infty$$?
#
# **c.** What happens when $$z\rightarrow-\infty$$?
#
# ---
#
# ## Q11. `predict_proba()` vs `predict()` — 3 marks
#
# Suppose:
#
# ```python
# model.predict_proba(X)
# ```
#
# returns:
#
# ```text
# P(class 0) = 0.91
# P(class 1) = 0.09
# ```
#
# What will:
#
# ```python
# model.predict(X)
# ```
#
# return by default?
#
# Would changing the classification threshold from `0.5` to `0.1` change the probability produced by the model?
#
# Explain.
#
# ---
#
# ## Q12. Log Loss — 3 marks
#
# Consider two predictions for a positive example:
#
# ```text
# Model A → P(Y=1) = 0.90
# Model B → P(Y=1) = 0.51
# ```
#
# Which model receives the lower log loss?
#
# Why?
#
# Now consider:
#
# ```text
# Model C → P(Y=1) = 0.01
# ```
#
# for the same positive example.
#
# Why is this prediction punished much more severely?
#
# ---
#
# ## Q13. Gradient — 3 marks
#
# For logistic regression, we discussed:
#
# $$
# \nabla J(\beta)=
# \frac{1}{n}X^T(p-y)
# $$
#
# Explain intuitively what the term:
#
# $$
# p-y
# $$
#
# represents.
#
# Why does the gradient tell us how to change the coefficients?
#
# ---
#
# # Section D — Regularization
#
# ## Q14. L2 Regularization — 3 marks
#
# Suppose the objective is:
#
# $$
# J(\beta)
# =
# LogLoss
# +
# \lambda\sum_j\beta_j^2
# $$
#
# What happens when \(\lambda\) becomes very large?
#
# What happens to the model coefficients?
#
# Why can this help with overfitting?
#
# ---
#
# ## Q15. `C` in scikit-learn — 2 marks
#
# In scikit-learn logistic regression and SVM we use `C` rather than directly specifying \(\lambda\).
#
# Conceptually:
#
# $$
# C\propto\frac{1}{\lambda}
# $$
#
# Therefore:
#
# **a.** What does a small `C` mean?
#
# **b.** What does a large `C` mean?
#
# ---
#
# # Section E — SVM
#
# ## Q16. Logistic Regression vs SVM — 4 marks
#
# Both logistic regression and Linear SVM can produce:
#
# $$
# f(x)=w^Tx+b
# $$
#
# So why are they different models?
#
# Explain the difference between:
#
# * what logistic regression optimizes
# * what SVM optimizes
#
# Use **log loss** and **hinge loss/margin** in your explanation.
#
# ---
#
# ## Q17. Margin — 3 marks
#
# Consider the following simplified situation:
#
# ```text
# Negative       Negative
#    ●              ●
#
#         ●
#
# -------------------------  decision boundary
#
#         ▲
#    ▲             ▲
# Positive      Positive
# ```
#
# What does SVM mean by the **margin**?
#
# Why does SVM try to maximize it?
#
# What are **support vectors**?
#
# ---
#
# ## Q18. Hinge Loss — 3 marks
#
# For:
#
# $$
# L=\max(0,1-yf(x))
# $$
#
# consider these three observations:
#
# ```text
# A: yf(x) = 2.0
# B: yf(x) = 0.5
# C: yf(x) = -1.0
# ```
#
# Calculate the hinge loss for each.
#
# Then explain what this tells us about how SVM treats correctly classified observations that are:
#
# * far from the boundary
# * close to the boundary
# * incorrectly classified
#
# ---
#
# # Section F — Evaluation
#
# ## Q19. ROC-AUC — 3 marks
#
# Explain what ROC-AUC measures.
#
# Suppose:
#
# ```text
# Model A ROC-AUC = 0.74
# Model B ROC-AUC = 0.60
# ```
#
# What does the higher AUC indicate?
#
# Does ROC-AUC depend on choosing a particular classification threshold?
#
# ---
#
# ## Q20. PR-AUC — 3 marks
#
# Our dataset has only about 8% positive cases.
#
# Why did we decide to track **PR-AUC in addition to ROC-AUC**?
#
# What do precision and recall represent?
#
# Why can PR-AUC be particularly informative for imbalanced classification?
#
# ---
#
# ## Q21. Threshold — 3 marks
#
# Our logistic model produced probabilities mostly below `0.5`.
#
# At threshold `0.5`, we obtained approximately:
#
# ```text
# Recall = 0
# ```
#
# Why does this not necessarily mean the model is useless?
#
# What changes when we reduce the threshold?
#
# ---
#
# # Section G — Model Selection & Experimental Thinking
#
# ## Q22. Controlled Experiment — 3 marks
#
# We compared:
#
# ```text
# Logistic Regression
# vs
# Linear SVM
# ```
#
# while keeping the feature matrix and preprocessing unchanged.
#
# Why is this a good experimental design?
#
# What would be wrong with changing the features, preprocessing, model, and hyperparameters simultaneously?
#
# ---
#
# ## Q23. Interpret Our SVM Result — 4 marks
#
# We obtained approximately:
#
# ```text
# Logistic Regression
# ROC-AUC ≈ 0.742
# PR-AUC  ≈ 0.220
#
# Linear SVM
# ROC-AUC ≈ 0.743
# PR-AUC  ≈ 0.220
# ```
#
# Then we changed SVM's `C`:
#
# ```text
# 0.01 → 0.10 → 1 → 10 → 100
# ```
#
# and ROC-AUC remained approximately:
#
# ```text
# 0.74265 – 0.74271
# ```
#
# What can we reasonably conclude from this experiment?
#
# What **should we not conclude**?
#
# ---
#
# ## Q24. Feature Engineering vs Model Selection — 4 marks
#
# Consider our progression:
#
# ```text
# Initial features
# ROC-AUC ≈ 0.632
#
# Feature engineering
# ROC-AUC ≈ 0.646
#
# + EXT_SOURCE features
# ROC-AUC ≈ 0.738
#
# + demographic features
# ROC-AUC ≈ 0.742
# ```
#
# What does this tell us about the relative importance of:
#
# **feature representation vs switching between linear classifiers?**
#
# Explain rather than simply stating the conclusion.
#
# ---
#
# # Section H — Final Case Study
#
# ## Q25. Put Everything Together — 5 marks
#
# You are given a new applicant:
#
# ```text
# AMT_INCOME_TOTAL = ₹150,000
# AMT_CREDIT       = ₹900,000
# AMT_ANNUITY      = ₹45,000
# DAYS_BIRTH       = -12,000
# DAYS_EMPLOYED    = 365243
# TARGET           = unknown
# ```
#
# You are asked to generate a prediction using our final model.
#
# Describe the complete pipeline you would follow, starting from the raw applicant data.
#
# Your answer should address:
#
# 1. Feature engineering
# 2. Sentinel-value handling
# 3. Ratio creation
# 4. Log transformations
# 5. Missing-value handling
# 6. Scaling
# 7. Categorical encoding
# 8. Model prediction
# 9. Probability/score interpretation
# 10. Classification threshold
#
# And answer this final question:
#
# > **Which of these steps should learn parameters from the applicant's own data, and which should use parameters learned from the training data?**
#
# ---
#
# # Challenge Question
#
# ## Q26. Think Like a Data Scientist — 5 marks
#
# Suppose someone tells you:
#
# > "Our model has 92% accuracy, so the model is excellent."
#
# You are given only the following information:
#
# ```text
# TARGET = 0 → 91.93%
# TARGET = 1 → 8.07%
# ```
#
# Write a response explaining why that conclusion is not justified.
#
# Your answer should discuss:
#
# * baseline accuracy
# * minority-class recall
# * precision
# * ROC-AUC
# * PR-AUC
# * threshold selection
# * business costs
#
# **Do not simply say "accuracy is misleading." Build the argument quantitatively.**
#
# ---
#
# # Scoring
#
# |     Score | Interpretation                                                                                       |
# | --------: | ---------------------------------------------------------------------------------------------------- |
# | **45–50** | Strong conceptual understanding; ready to move deeper into feature engineering/model experimentation |
# | **38–44** | Good understanding; a few concepts need reinforcement                                                |
# | **30–37** | Working knowledge but important gaps remain                                                          |
# | **20–29** | Several foundational concepts need revision                                                          |
# |   **<20** | Revisit the modeling fundamentals before adding more models                                          |
#
# ## Test Rule
#
# Try to answer **without looking back at our previous discussion**.
#
# The objective is not simply to remember definitions. The test is designed to distinguish between:
#
# * concepts you genuinely understand,
# * concepts you can apply,
# * and concepts you have only memorized.
#
# After completing it, send me your answers. I will grade them **question by question**, explain mistakes, and identify exactly which concepts we should revisit before continuing with the Home Credit model.
